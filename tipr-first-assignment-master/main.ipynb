# %% [markdown]
# # Random Projections

# %%
import numpy as np
from sklearn.random_projection import GaussianRandomProjection
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
import csv
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
from numpy import genfromtxt
import math

# %% [markdown]
# ## dolphin

# %%
X = genfromtxt('./data/dolphins/dolphins.csv', delimiter=' ')

# %%
labels = genfromtxt('./data/dolphins/dolphins_label.csv')

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import neighbors

# %%
#TASK 1
#for saving the data
for d in range(2,int(K/2)+2,2):
    transformer = GaussianRandomProjection(n_components=d)
    X_new = transformer.fit_transform(X)
    with open('./data/dolphins/dolph'+str(d)+'.csv', mode='w') as file:
        writer = csv.writer(file, delimiter=' ', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        for row in X_new:
            writer.writerow(row)

# %%
K = X.shape[1]

#TASK 2 AND 3
acc = []
f1mac = []
f1mic = []
acc1 = []
f1mac1 = []
f1mic1 = []
for d in range(2,int(K/2)+2,2):
    transformer = GaussianRandomProjection(n_components=d)
    X_new = transformer.fit_transform(X) 
    X_train, X_test, y_train, y_test = train_test_split(X_new, labels, test_size=0.33, random_state=42) 
    print(X_train.shape)
    gnb = GaussianNB()
    gnb.fit(X_train, y_train)
    y_pred = gnb.predict(X_test)
    acc.append(accuracy_score(y_test, y_pred))
    f1mac.append(f1_score(y_test,y_pred,average='macro'))
    f1mic.append(f1_score(y_test,y_pred,average='micro'))
    nnclf = neighbors.KNeighborsClassifier(2, weights='uniform')
    nnclf.fit(X_train, y_train)
    y_pred = nnclf.predict(X_test)
    acc1.append(accuracy_score(y_test, y_pred))
    f1mac1.append(f1_score(y_test,y_pred,average='macro'))
    f1mic1.append(f1_score(y_test,y_pred,average='micro'))

plt.plot(list(range(2,int(K/2)+2,2)),acc)
plt.plot(list(range(2,int(K/2)+2,2)),acc1)

plt.title('accuracy vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('accuracy')
plt.legend(['gnb','nn'],loc=0)
plt.show()
plt.plot(list(range(2,int(K/2)+2,2)),f1mac)
plt.plot(list(range(2,int(K/2)+2,2)),f1mac1)

plt.title('f1macro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1 macro')
plt.legend(['gnb','nn'],loc=0)

plt.show()
plt.plot(list(range(2,int(K/2)+2,2)),f1mic)
plt.plot(list(range(2,int(K/2)+2,2)),f1mic1)

plt.title('f1micro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1micro')
plt.legend(['gnb','nn'],loc=0)

plt.show()
# Out:
# (41, 2)
# (41, 4)
# (41, 6)
# (41, 8)
# (41, 10)
# (41, 12)
# (41, 14)
# (41, 16)
# /home/vishay/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## pubmed

# %%
X = genfromtxt('./data/pubmed/pubmed.csv', delimiter=' ')

labels = genfromtxt('./data/pubmed/pubmed_label.csv')

# %%
K = X.shape[1]

# %%
#TASK 2 AND 3
acc = []
f1mac = []
f1mic = []
acc1 = []
f1mac1 = []
f1mic1 = []
for d in range(2,int(K/2)+2,2):
    transformer = GaussianRandomProjection(n_components=d)
    X_new = transformer.fit_transform(X) 
    X_train, X_test, y_train, y_test = train_test_split(X_new, labels, test_size=0.33, random_state=42) 
    print(X_train.shape)
    gnb = GaussianNB()
    gnb.fit(X_train, y_train)
    y_pred = gnb.predict(X_test)
    acc.append(accuracy_score(y_test, y_pred))
    f1mac.append(f1_score(y_test,y_pred,average='macro'))
    f1mic.append(f1_score(y_test,y_pred,average='micro'))
    nnclf = neighbors.KNeighborsClassifier(2, weights='uniform')
    nnclf.fit(X_train, y_train)
    y_pred = nnclf.predict(X_test)
    acc1.append(accuracy_score(y_test, y_pred))
    f1mac1.append(f1_score(y_test,y_pred,average='macro'))
    f1mic1.append(f1_score(y_test,y_pred,average='micro'))
# Out:
# (13869, 2)
# (13869, 4)
# (13869, 6)
# /home/vishay/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# (13869, 8)
# (13869, 10)
# (13869, 12)
# (13869, 14)
# (13869, 16)
# (13869, 18)
# (13869, 20)
# (13869, 22)
# (13869, 24)
# (13869, 26)
# (13869, 28)
# (13869, 30)
# (13869, 32)
# (13869, 34)
# (13869, 36)
# (13869, 38)
# (13869, 40)
# (13869, 42)
# (13869, 44)
# (13869, 46)
# (13869, 48)
# (13869, 50)
# (13869, 52)
# (13869, 54)
# (13869, 56)
# (13869, 58)
# (13869, 60)
# (13869, 62)
# (13869, 64)

# %%
plt.plot(list(range(2,int(K/2)+2,2)),acc)
plt.plot(list(range(2,int(K/2)+2,2)),acc1)

plt.title('accuracy vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('accuracy')
plt.legend(['gnb','nn'],loc=0)
plt.show()
plt.plot(list(range(2,int(K/2)+2,2)),f1mac)
plt.plot(list(range(2,int(K/2)+2,2)),f1mac1)

plt.title('f1macro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1 macro')
plt.legend(['gnb','nn'],loc=0)

plt.show()
plt.plot(list(range(2,int(K/2)+2,2)),f1mic)
plt.plot(list(range(2,int(K/2)+2,2)),f1mic1)

plt.title('f1micro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1micro')
plt.legend(['gnb','nn'],loc=0)

plt.show()

# %% [markdown]
# ## twitter

# %%
data = open('./data/twitter/twitter.txt', 'r').read().splitlines()

labels = open('./data/twitter/twitter_label.txt', 'r').read().splitlines()

label = [int(i) for i in labels]

y = np.array(labels)

from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X = count_vect.fit_transform(data)

# %%
X.shape[1]
# Out:
# 2978

# %%
#TASK 2 AND 3
acc = []
f1mac = []
f1mic = []
acc1 = []
f1mac1 = []
f1mic1 = []
for d in range(2,int(K/2)+2,2):
    transformer = GaussianRandomProjection(n_components=d)
    X_new = transformer.fit_transform(X) 
    X_train, X_test, y_train, y_test = train_test_split(X_new, labels, test_size=0.33, random_state=42) 
    print(X_train.shape)
    gnb = GaussianNB()
    gnb.fit(X_train, y_train)
    y_pred = gnb.predict(X_test)
    acc.append(accuracy_score(y_test, y_pred))
    f1mac.append(f1_score(y_test,y_pred,average='macro'))
    f1mic.append(f1_score(y_test,y_pred,average='micro'))
    nnclf = neighbors.KNeighborsClassifier(2, weights='uniform')
    nnclf.fit(X_train, y_train)
    y_pred = nnclf.predict(X_test)
    acc1.append(accuracy_score(y_test, y_pred))
    f1mac1.append(f1_score(y_test,y_pred,average='macro'))
    f1mic1.append(f1_score(y_test,y_pred,average='micro'))

plt.plot(list(range(2,int(920)+2,2)),acc)
plt.plot(list(range(2,int(918)+2,2)),acc1)

plt.title('accuracy vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('accuracy')
plt.legend(['gnb','nn'],loc=0)
plt.show()
plt.plot(list(range(2,int(920)+2,2)),f1mac)
plt.plot(list(range(2,int(918)+2,2)),f1mac1)

plt.title('f1macro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1 macro')
plt.legend(['gnb','nn'],loc=0)

plt.show()
plt.plot(list(range(2,int(920)+2,2)),f1mic)
plt.plot(list(range(2,int(918)+2,2)),f1mic1)

plt.title('f1micro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1micro')
plt.legend(['gnb','nn'],loc=0)

plt.show()

# %% [markdown]
# ## pca

# %%
import numpy as np
from sklearn.decomposition import PCA
X = genfromtxt('./data/dolphins/dolphins.csv', delimiter=' ')
labels = genfromtxt('./data/dolphins/dolphins_label.csv')

K = X.shape[1]

#TASK 2 AND 3
acc = []
f1mac = []
f1mic = []
acc1 = []
f1mac1 = []
f1mic1 = []
for d in range(5,16):
    pca = PCA(n_components=d)
    X_new = pca.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_new, labels, test_size=0.33, random_state=42) 
    #print(X_train.shape)
    gnb = GaussianNB()
    gnb.fit(X_train, y_train)
    y_pred = gnb.predict(X_test)
    acc.append(accuracy_score(y_test, y_pred))
    f1mac.append(f1_score(y_test,y_pred,average='macro'))
    f1mic.append(f1_score(y_test,y_pred,average='micro'))
    nnclf = neighbors.KNeighborsClassifier(2, weights='uniform')
    nnclf.fit(X_train, y_train)
    y_pred = nnclf.predict(X_test)
    acc1.append(accuracy_score(y_test, y_pred))
    f1mac1.append(f1_score(y_test,y_pred,average='macro'))
    f1mic1.append(f1_score(y_test,y_pred,average='micro'))

plt.plot(list(range(5,16)),acc)
plt.plot(list(range(5,16)),acc1)

plt.title('accuracy vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('accuracy')
plt.legend(['gnb','nn'],loc=0)
plt.show()
plt.plot(range(5,16),f1mac)
plt.plot(range(5,16),f1mac1)

plt.title('f1macro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1 macro')
plt.legend(['gnb','nn'],loc=0)

plt.show()
plt.plot(list(range(5,16)),f1mic)
plt.plot(list(range(5,16)),f1mic1)

plt.title('f1micro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1micro')
plt.legend(['gnb','nn'],loc=0)

plt.show()
# Out:
# /home/vishay/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
X = genfromtxt('./data/pubmed/pubmed.csv', delimiter=' ')

labels = genfromtxt('./data/pubmed/pubmed_label.csv')

# %%
K = X.shape[1]

#TASK 2 AND 3
acc = []
f1mac = []
f1mic = []
acc1 = []
f1mac1 = []
f1mic1 = []
for d in range(5,16):
    pca = PCA(n_components=d)
    X_new = pca.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_new, labels, test_size=0.33, random_state=42) 
    #print(X_train.shape)
    gnb = GaussianNB()
    gnb.fit(X_train, y_train)
    y_pred = gnb.predict(X_test)
    acc.append(accuracy_score(y_test, y_pred))
    f1mac.append(f1_score(y_test,y_pred,average='macro'))
    f1mic.append(f1_score(y_test,y_pred,average='micro'))
    nnclf = neighbors.KNeighborsClassifier(2, weights='uniform')
    nnclf.fit(X_train, y_train)
    y_pred = nnclf.predict(X_test)
    acc1.append(accuracy_score(y_test, y_pred))
    f1mac1.append(f1_score(y_test,y_pred,average='macro'))
    f1mic1.append(f1_score(y_test,y_pred,average='micro'))

plt.plot(list(range(5,16)),acc)
plt.plot(list(range(5,16)),acc1)

plt.title('accuracy vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('accuracy')
plt.legend(['gnb','nn'],loc=0)
plt.show()
plt.plot(range(5,16),f1mac)
plt.plot(range(5,16),f1mac1)

plt.title('f1macro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1 macro')
plt.legend(['gnb','nn'],loc=0)

plt.show()
plt.plot(list(range(5,16)),f1mic)
plt.plot(list(range(5,16)),f1mic1)

plt.title('f1micro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1micro')
plt.legend(['gnb','nn'],loc=0)

plt.show()

# %%
data = open('./data/twitter/twitter.txt', 'r').read().splitlines()

labels = open('./data/twitter/twitter_label.txt', 'r').read().splitlines()

label = [int(i) for i in labels]

y = np.array(labels)

from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X = count_vect.fit_transform(data)

# %%
from sklearn.decomposition import TruncatedSVD

# %%
acc = []
f1mac = []
f1mic = []
acc1 = []
f1mac1 = []
f1mic1 = []
for d in range(5,16):
    svd = TruncatedSVD(n_components=d)
    X_new = svd.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_new, labels, test_size=0.33, random_state=42) 
    #print(X_train.shape)
    gnb = GaussianNB()
    gnb.fit(X_train, y_train)
    y_pred = gnb.predict(X_test)
    acc.append(accuracy_score(y_test, y_pred))
    f1mac.append(f1_score(y_test,y_pred,average='macro'))
    f1mic.append(f1_score(y_test,y_pred,average='micro'))
    nnclf = neighbors.KNeighborsClassifier(2, weights='uniform')
    nnclf.fit(X_train, y_train)
    y_pred = nnclf.predict(X_test)
    acc1.append(accuracy_score(y_test, y_pred))
    f1mac1.append(f1_score(y_test,y_pred,average='macro'))
    f1mic1.append(f1_score(y_test,y_pred,average='micro'))

plt.plot(list(range(5,16)),acc)
plt.plot(list(range(5,16)),acc1)

plt.title('accuracy vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('accuracy')
plt.legend(['gnb','nn'],loc=0)
plt.show()
plt.plot(range(5,16),f1mac)
plt.plot(range(5,16),f1mac1)

plt.title('f1macro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1 macro')
plt.legend(['gnb','nn'],loc=0)

plt.show()
plt.plot(list(range(5,16)),f1mic)
plt.plot(list(range(5,16)),f1mic1)

plt.title('f1micro vs number of dimensions')
plt.xlabel('number of components')
plt.ylabel('f1micro')
plt.legend(['gnb','nn'],loc=0)

plt.show()

# %% [markdown]
# # bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(my_data[0:int(.8*len(my_data)),:], labels[0:int(.8*len(my_data))])
# Out:
# GaussianNB(priors=None)

# %%
y_pred = gnb.predict(my_data[int(.8*len(my_data))+1:,:])

# %%
count = 0
for i in range(len(y_pred)):
    if y_pred[i] ==

# %%
y_pred
# Out:
# array([1., 1., 2., 2., 2., 1., 0., 1., 0., 0., 0., 1.])

# %%
labels[int(.8*len(my_data))+1:]
# Out:
# array([1., 1., 2., 2., 2., 1., 0., 3., 0., 0., 0., 1.])

# %%
count = 0
for i in range(len(y_pred)):
    if y_pred[i] == labels[int(.8*len(my_data))+1:][i]:
        count+=1
print(count/len(labels[int(.8*len(my_data))+1:]))
# Out:
# 0.9166666666666666

# %% [markdown]
# # NN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(my_data[0:int(.8*len(my_data)),:], labels[0:int(.8*len(my_data))])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
NN_pred = neigh.predict(my_data[int(.8*len(my_data))+1:,:])

# %%
labels[int(.8*len(my_data))+1:]
# Out:
# array([1., 1., 2., 2., 2., 1., 0., 3., 0., 0., 0., 1.])

# %%
count = 0
for i in range(len(y_pred)):
    if NN_pred[i] == labels[int(.8*len(my_data))+1:][i]:
        count+=1
print(count/len(labels[int(.8*len(my_data))+1:]))
# Out:
# 0.8333333333333334

# %% [markdown]
# # Bayes from scratch

# %%
def separateByClass(dataset, gt):
    separated = {}
    for i in range(len(dataset)):
        vector = dataset[i]
        if (int(gt[i]) not in separated):
            separated[int(gt[i])] = []
        separated[int(gt[i])].append(vector)
    return separated

# %%
def prior(class_label,sep,data):
    return len(sep[class_label])/len(data)

# %%
def summarizeByClass(dataset,gt):
    separated = separateByClass(dataset,gt)
    summaries = {}
    for classValue, instances in separated.items():
        summaries[classValue] = summarize(instances)
    return summaries

# %%
def summarize(dataset):
    summaries = [np.mean(dataset,axis = 0), np.std(dataset,axis = 0)]
  #  del summaries[-1]
    return summaries

# %%
def calculateProbability(x, mean, stdev):
    exponent = math.exp(-(math.pow(x-mean,2)/(2*math.pow(stdev,2))))
    return (1 / (math.sqrt(2*math.pi) * stdev)) * exponent
 
def calculateClassProbabilities(summaries, inputVector):
    global priors
    probabilities = {}
    for classValue, classSummaries in summaries.items():
        clsms = np.array(classSummaries)
        probabilities[classValue] = priors[0][classValue]
        for i in range(np.shape(clsms)[1]):
            mean = clsms[0,i]
            stdev = clsms[1,i]
            x = inputVector[i]
            probabilities[classValue] *= calculateProbability(x, mean, stdev)
    return probabilities

# %%
def predict(summaries, inputVector):
    probabilities = calculateClassProbabilities(summaries, inputVector)
    bestLabel, bestProb = None, -1
    for classValue, probability in probabilities.items():
        if bestLabel is None or probability > bestProb:
            bestProb = probability
            bestLabel = classValue
    return bestLabel
 
def getPredictions(summaries, testSet):
    predictions = []
    for i in range(len(testSet)):
        result = predict(summaries, testSet[i])
        predictions.append(result)
    return predictions

def getAccuracy(testSet, predictions):
    correct = 0
    for i in range(len(testSet)):
        if testSet[i][-1] == predictions[i]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0

# %%
summaries = summarizeByClass(my_data,labels)

# %%
separated = separateByClass(my_data,labels)
summaries = {}
for classValue, instances in separated.items():
    summaries[classValue] = instances

# %%
priors = np.zeros((1,len(set(labels))))
for i in range(len(set(labels))):
    priors[0,i] = prior(i,s,my_data)

# %%
s = separateByClass(my_data,labels)

# %%
predictions = getPredictions(summaries, my_data)

# %%
count = 0
for i in range(len(my_data)):
    if labels[i] == predictions[i]:
        count += 1
print(count/len(my_data)*100)
# Out:
# 96.7741935483871

# %% [markdown]
# # NN From Scratch

# %%
#import csv
#import random
import math
#import operator
import numpy as np

# %%
def euclideanDistance(a,b):
    return np.linalg.norm(a-b)

def prediction(trainingSet, testInstance, k):
    distances = []
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x])
        distances.append(dist)
    neighbor = np.argmin(distances)
    
    global labels
    return labels[neighbor]

# %%
distances = []
trainingSet = my_data
testInstance = my_data[0,:]
length = len(testInstance)-1
for x in range(len(trainingSet)):
    dist = euclideanDistance(testInstance, trainingSet[x])
    distances.append(dist)
neighbor = np.argmin(distances)

# %%
neighbor
# Out:
# 0

# %%
distances[0]
# Out:
# 0.0
